# %% [markdown]
# <a href="https://colab.research.google.com/github/Daffonill/Python_NP/blob/main/Python_NP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/NextGen-AI-Camp/curriculum/blob/main/Week%232/Python%233/NextGen_AI_Camp_Python%233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data types in Python
# ประเภทข้อมูลใน Python

# %% [markdown]
# ##Numbers
# - `int` for integers
# - `float` for real numbers. They can represent decimal points.
# - `complex` for complex numbers(with real and imaginary parts,very scientific!)

# %% [markdown]
# To represent `int` values in the program,type *numbers* without decimal points.

# %%
print(32)

# %%
print(type(32))

# %% [markdown]
# `type()`can be used for checking the data types of any values.

# %%
print(type(32))

# %% [markdown]
# To represent `float` values in the program, type *numbers with decimal points*.

# %%
print(5.0)

# %%
print(5.22)

# %%
print(type(5.0))

# %% [markdown]
# To represent `complex` values in the program, use the format `a+bj`.

# %%
print(5+3j)

# %%
print(2+3j)

# %% [markdown]
# จงเขียนโปรค่าให้ตัวแปร a,b,c เป็นค่าข้อมูลชนิด int,float,complex ตามลำดับ ให้นักเรียน *print()* ค่าแต่ละตัวแปรออกมาและเช็คค่าข้อมูลด้วยคำสั่ง *type()* และแสดงผลลัพธ์ค่าจากการเช็คชนิดข้อมูล

# %% [markdown]
# ## Strings
# A string object is a sequence of chracters. In Python, the data type is `str`.
# To represent `str` in the program,enclose text with quotes.
#
# Quotes could be:
# - Single quotes
# - Dobule quotes
# - Triple quotes

# %% [markdown]
# ***Todo***
#
# ให้ใช้คำสั่ง print พิมพ์ข้อความ ต่อไปนี้ออกจอภาพ
#
# Python Print Function
# The function is declared like this:
# print('what to print')

# %%
print('Hello')
print("Hello")
print('''Hello''')
print(type('Hello'))
print(type("Hello"))
print(type('''Hello'''))

# %%
print("32")
print(type("32"))

# %% [markdown]
# เราสามารถสั่งให้ขึ้นบรรทัดใหม่ ใน string เดียวกัน โดยใช้อักขระพิเศษ \n มีความหมาย = new line หรือ ขึ้นบรรทัดใหม่

# %%
print("Python Print Function\nThe function is declared like this:\nprint('what to print')")

# %% [markdown]
# ให้นักเรียน *print()* ชื่อ,นามสกุล,ชั้น,เลขที่ โดยข้อความแต่ละข้อความต้องอยู่คนละบรรทัดกัน

# %% [markdown]
# String สามารถเอามาต่อกันได้โดยเครื่องหมาย + (เรียกว่า String Operator)

# %%
print("Hello," + " NextGen AI Camper")

# %% [markdown]
# ให้นักเรียน *print()* ข้อความ Hello, My name is (your name).I am (Your age) years old. โดยใช้เครื่องหมาย +

# %% [markdown]
# Since quotes are used for singnaling the starting/ending of a String object, how can we write a sentence
# like *He said "Hello"* or *It's ok to say "Goodbye"*.

# %%
# print("He said "Hello"") คอมพิวเตอร์จะสับสน ว่าเรา quotes ข้อความอันไหน ดังนั้นจึงต้องแก้
print('He said "Hello".') #โดยการใช้ quotes ที่แตกต่างกัน
print('''It's ok to say "Goodbye".''')

# %% [markdown]
# ให้นักเรียนใช้คำสั่ง *print()* แสดงข้อความ
# "Don't watch the clock; do what it does. Keep going."

# %% [markdown]
# If switching quotes is NOT a choice(ไม่ต้องการเปลี่ยน quotes),we can *escape* the quote character with a backslash.

# %%
print("He said \"Hello\"")
print("It's ok to say \"Goodbye\".")
#พิมพ์ \ เพื่อบอกว่าเป็น Double quotes.

# %% [markdown]
# ## Boolean
# We type keywords `True` and `False`to represent the(truth) value *true* and *false*,respectively.

# %%
print(True)
print(False)
print(type(True))
print(type(False))

# %%
print(true)
print(false)

# %%
T = True
T and False

# %% [markdown]
# ## การกระทำแบบเปรียบเทียบ
#
# เราสามารถเปรียบเทียบตัวแปร นิพจน์ หรือ อะไรก็ตามได้ โดยจะให้ผลเป็น Boolean
#
# <img src="https://www.devopsschool.com/blog/wp-content/uploads/2020/08/relational-operator-in-python.png" width="500">อ

# %% [markdown]
# ให้ใช้คำสั่ง *print()* ในการเช็คข้อความดังต่อไปนี้
#
# 42 < 100
#
# 42 < 42
#
# 42 == 42.0
#
# 42 == '42'

# %% [markdown]
# Be reminded that Python is *case-sensitive*. Therefore,`true`and`false` are ***Not boolean values***
#
# If you wanna use boolean, you must type `True`and`False`

# %% [markdown]
# ## Operators

# %% [markdown]
# ![Precedence of operator.png](data:image/png;base64,...)

# %% [markdown]
# ![Order-of-Operators.png](data:image/png;base64,...)

# %% [markdown]
# * ถ้า Precedence เท่ากัน จะทำจาก *ซ้าย ไป ขวา*
# * **ยกเว้น** การยกกำลังและการใส่ค่าตัวแปร ที่จะทำจาก *ขวา ไป ซ้าย*

# %%
a = 20
b = 5
print(a + b) # Addition
print(a - b) # Substration
print(a * b) # Multiplication
print(a / b) # Division

# %% [markdown]
# ## การเขียนอย่างย่อ
#
# ในกรณีที่เราเขียนคำสั่งที่มีลักษณะเป็น a = a + b เราสามารถเขียนแบบย่อได้
#
# - a = a + b สามารถเขียนเป็น a += b
# - a = a - b สามารถเขียนเป็น a -= b
# - a = a * b สามารถเขียนเป็น a *= b
# - a = a / b สามารถเขียนเป็น a /= b

# %% [markdown]
# - ข้อที่ควรระวังอย่างหนึ่งของการคำนวณทางคณิตศาสตร์ คือ ชนิดข้อมูลของผลลัพธ์การคำนวณ ซึ่งอาจจะไม่ตรงกับข้อมูลที่นำมากระทำกัน
# เช่น ข้อมูล int หารด้วย int จะได้ชนิดข้อมูลเป็น float
# - ถือเป็นหลักง่ายๆ ก็ได้ว่า ถ้าข้อมูลชนิด float ทำ operation กับข้อมูลชนิดอื่นผลลัพธ์จะได้เป็น float แต่ถ้า int กับ int หารกันจะได้เป็น float เสมอ

# %%
a = 20
b = 5
a += b
print(a)

# %%
a = 30
b = 5
a -= b
print(a)

# %% [markdown]
# ## Unary Minus
# A unary minus *inverses the polarity* of the numeric operand

# %%
a = 2
print(-a)
b = -5
print(-b)

# %% [markdown]
# ## Modulus
# A modulus (`a % b` reads as "a modulo b") finds the *remainder* resulting from dividing the left operand (`a`) with the right operand (`b`).

# %%
x = 25
print(x % 4) # Since 25 = 4*6 + 1
print(x % 5) # Since 25 = 5*5 + 0
print(x % 7) # Since 25 = 7*3 + 4

# %% [markdown]
# ## Exponentiation
# An exponentiation (`a ** b`)finds the value of the left operand(`a`)raised to the power of the value of the right operand(`b`).

# %%
print(2 ** 3)
print(5 ** 4)
print(29 ** 0) # Since any numbers raised to the power of 0 is 1
print(2 ** -1) # Since it is 1/2

# %% [markdown]
# ### Floor Division
# A floor division (`//`)is a *division* that *rounds* the result down to the nearest *integer*(the next smaller integer).

# %%
print(32 / 3)
print(32 // 3)
print(-32 / 3)
print(-32 // 3)

# %% [markdown]
# ## Comparison Operators
# A comparison operator *compares two values*. it returns `True` or `False`

# %%
a = 20
print(a == 20) # is equal to ?
print(a != 20) # is NOT equal to ?
print(a > 20) # is grater than ?
print(a < 20) # is less than ?
print(a >= 20) # is greater than or equal to ?
print(a <= 20) # is less than or equal to ?

# %% [markdown]
# ## Logical Operators
# A logical operator performs a *boolean operation*(AND,OR,NOT)

# %%
p = True
q = False
# and
print(p and p)
print(p and q)
print(q and q)
# or
print(p or p)
print(p or q)
print(q or q)
# not
print(not p)
print(not q)

# %% [markdown]
# # Variables
# We **assign** values to variables and, later on,**refer** to the variable names to use the values.

# %%
a = 3 # Assign the value 3 to the variable named a
b = 5.5 #Assign the value 5.5 to another variable named b
print(a)
print(b)

# %%
firstname = "Sasiporn"
lastname = "Saeimi"
print(firstname)
print(lastname)

# %%
a = b = "Hello"
print(a)
print(b)

# %%
a , b , c = "Hello" , 45 , True
print(a)
print(b)
print(c)

# %% [markdown]
# ## คำสั่ง Input
#
# คำสั่ง Input ใช้ในการรับข้อมูล โดยมีรูปแบบการใช้งาน คือ
#
#
# ```
# Input(Prompt)
# ```
#
# โดย Prompt คือ ข้อความที่จะแสดงให้รู้ว่าต้องการข้อมูลอะไร

# %%
input("What is your name : ")

# %%
print("Hello " + input("What is your name : "))

# %% [markdown]
# ข้อมูลที่รับเข้ามา จะมีชนิดเป็น string ดังนั้นหากต้องการรับข้อมูลประเภทตัวเลข จะต้องมีการแปลงเสียก่อน

# %%
in1 = input('Enter first number : ')
in2 = input('Enter second number : ')
print(in1+in2)
print(int(in1)+int(in2))

# %% [markdown]
# ## การรับ Input ครั้งละหลายค่า
#
# เราสามารถรับ Input ครั้งละหลายค่าได้

# %%
x,y = [int(e) for e in input().split()]     # ป้อน int x,y
print(x,y,x+y)

# %%
x = int(input())
y = float(input())
print(x+y)

# %% [markdown]
# https://pythontutor.com/

# %% [markdown]
# #Exercise
#
# 1.	จงเขียนโปรแกรม เพื่อคํานวณหาพื้นที่ของสามเหลี่ยม Area = ½ x ฐาน x สูง  โดยมีข้อมูลเข้า  (Input) จากคีย์บอร์ด คือ ค่าของฐานของสามเหลี่ยม (b: Base) และค่าความสูงของสามเหลี่ยม (h: Height)
# 2.	จงเขียนโปรแกรม เพื่อคํานวณหาปริมาตรของรูปทรงกระบอก Volume = Area x H โดยมีข้อมูลเข้า (Input) จากคีย์บอร์ด คือ ค่าของรัศมีของวงกลม (r: Radius) ที่เป็นฐานของรูปทรงกระบอก และค่าความสูงของรูปทรงกระบอก (h: Height) ตามลําดับ
# วิธีการคํานวณ ปริมาตร =(π =3.14) * r * r * h
# 3.	จงเขียนโปรแกรม เพื่อคํานวณคะแนนรวมของผลสอบวิชา Programming จากคะแนน Mid-term, คะแนน Final, และคะแนน Homework เป็นข้อมูลเข้า (Input) จากคีย์บอร์ด และแสดงผลลัพธ์จากการ คํานวณ เมื่อ
# คะแนนรวม (Total) = Mid-term (40%) + Final (50%) + HW (10%)
# 4.	จงเขียนโปรแกรม เพื่อคํานวณค่าเฉลี่ย (Mean) ของข้อมูล (Input) 4 ค่าที่รับจากคีย์บอร์ด คั่นด้วยช่องว่าง เพื่อเก็บในตัว แปร (x1, x2, x3, x4)  และแสดงผลลัพธ์ จากการคํานวณ เมื่อ Mean = (x1+x2+x3+x4) / 4
